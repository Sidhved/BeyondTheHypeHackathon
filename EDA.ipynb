# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import joblib

# %%
# Load Data
inputs = pd.read_csv('data/inputs.csv')
labels = pd.read_csv('data/labels.csv')
data = pd.concat([inputs, labels['HadHeartAttack']], axis=1)

# %%
def preprocess_data(df):
    # Create a copy to avoid modifying original data
    df_processed = df.copy()
    
    # Identify object columns
    object_columns = df.select_dtypes(include=['object']).columns
    
    # Initialize label encoders dictionary
    encoders = {}
    
    # Process each object column
    for column in object_columns:
        encoders[column] = LabelEncoder()
        df_processed[column] = encoders[column].fit_transform(df[column])
    
    return df_processed, encoders

processed_inputs, encoders = preprocess_data(data)

# %%
# Basic info
print("Data Info:")
print(processed_inputs.info())
print("\nLabel Distribution:")
print(processed_inputs['HadHeartAttack'].value_counts(normalize=True))
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190157 entries, 0 to 190156
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   PatientID                  190157 non-null  int64
#  1   State                      190157 non-null  int64
#  2   Sex                        190157 non-null  int64
#  3   GeneralHealth              190157 non-null  int64
#  4   AgeCategory                190157 non-null  int64
#  5   HeightInMeters             190157 non-null  float64
#  6   WeightInKilograms          190157 non-null  float64
#  7   BMI                        190157 non-null  float64
#  8   HadAngina                  190157 non-null  int64
#  9   HadStroke                  190157 non-null  int64
#  10  HadAsthma                  190157 non-null  int64
#  11  HadSkinCancer              190157 non-null  int64
#  12  HadCOPD                    190157 non-null  int64
#  13  HadDepressiveDisorder      190157 non-null  int64
#  14  HadKidneyDisease           190157 non-null  int64
#  15  HadArthritis               190157 non-null  int64
#  16  HadDiabetes                190157 non-null  int64
#  17  DeafOrHardOfHearing        190157 non-null  int64
#  18  BlindOrVisionDifficulty    190157 non-null  int64
#  19  DifficultyConcentrating    190157 non-null  int64
#  20  DifficultyWalking          190157 non-null  int64
#  21  DifficultyDressingBathing  190157 non-null  int64
#  22  DifficultyErrands          190157 non-null  int64
#  23  SmokerStatus               190157 non-null  int64
#  24  ECigaretteUsage            190157 non-null  int64
#  25  ChestScan                  190157 non-null  int64
#  26  RaceEthnicityCategory      190157 non-null  int64
#  27  AlcoholDrinkers            190157 non-null  int64
#  28  HIVTesting                 190157 non-null  int64
#  29  FluVaxLast12               190157 non-null  int64
#  30  PneumoVaxEver              190157 non-null  int64
#  31  TetanusLast10Tdap          190157 non-null  int64
#  32  HighRiskLastYear           190157 non-null  int64
#  33  CovidPos                   190157 non-null  int64
#  34  HadHeartAttack             190157 non-null  int64
# dtypes: float64(3), int64(32)
# memory usage: 50.8 MB
# None
#
# Label Distribution:
# HadHeartAttack
# 0    0.944404
# 1    0.055596
# Name: proportion, dtype: float64

# %%
# Target correlation analysis
target_corr = processed_inputs.corr()['HadHeartAttack'].sort_values(ascending=False)
print("\nCorrelation with target variable:")
print(target_corr)
# Out:
# Correlation with target variable:
# HadHeartAttack               1.000000
# HadAngina                    0.445970
# HadStroke                    0.175919
# AgeCategory                  0.173458
# ChestScan                    0.169416
# DifficultyWalking            0.159516
# HadDiabetes                  0.137834
# HadCOPD                      0.132328
# PneumoVaxEver                0.122172
# HadArthritis                 0.117649
# HadKidneyDisease             0.108911
# DeafOrHardOfHearing          0.096886
# DifficultyErrands            0.089696
# DifficultyDressingBathing    0.083397
# BlindOrVisionDifficulty      0.073390
# Sex                          0.070952
# DifficultyConcentrating      0.051804
# HadSkinCancer                0.050031
# FluVaxLast12                 0.047062
# WeightInKilograms            0.037117
# BMI                          0.030193
# RaceEthnicityCategory        0.024931
# HadAsthma                    0.024779
# HadDepressiveDisorder        0.023184
# HeightInMeters               0.021084
# TetanusLast10Tdap            0.010941
# State                       -0.001457
# PatientID                   -0.003363
# HIVTesting                  -0.013093
# ECigaretteUsage             -0.016642
# CovidPos                    -0.020012
# HighRiskLastYear            -0.020730
# GeneralHealth               -0.021796
# AlcoholDrinkers             -0.075126
# SmokerStatus                -0.076817
# Name: HadHeartAttack, dtype: float64

# %%
# Visualizations
plt.figure(figsize=(12, 8))
target_corr.drop('HadHeartAttack').plot(kind='bar')
plt.title('Feature Correlation with Target')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Overall correlation heatmap
plt.figure(figsize=(20, 16))
sns.heatmap(processed_inputs.corr(), 
            annot=True,
            cmap='coolwarm',
            center=0,
            fmt='.2f',
            square=True,
            cbar_kws={"shrink": .5},
            annot_kws={'size': 8})
plt.title('Feature Correlation Matrix')
plt.tight_layout()
plt.show()

# %%
# Save processed data and encoders
processed_inputs.to_csv('data/processed_inputs.csv', index=False)
joblib.dump(encoders, 'data/encoders.joblib')
# Out:
# ['data/encoders.joblib']
